# %% [markdown]
# # TUGAS BESAR ANALISIS DAN VISUALISASI DATA
# # NAMA ANGGOTA KELOMPOK:
# # 1. Fitri Fatimah (2C2230004)
# # 2. Nadine Valia Azzahra (2C2230007)
# # 3. Kanaya Dzikra Setiadi (2C2230015)
# # 4. Amelia Regina Permana (2C2230019)

# %%
# !pip install pandas

import pandas as pd
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df = pd.read_csv('C:/TUGAS SEMESTER 3/Pemrograman Lanjut/cards_data.csv')
df
# Out:
#         id  client_id  card_brand        card_type       card_number  expires  \
# 0     4524        825        Visa            Debit  4344676511950444  12/2022
# 1     2731        825        Visa            Debit  4956965974959986  12/2020
# 2     3701        825        Visa            Debit  4582313478255491  02/2024
# 3       42        825        Visa           Credit  4879494103069057  08/2024
# 4     4659        825  Mastercard  Debit (Prepaid)  5722874738736011  03/2009
# ...    ...        ...         ...              ...               ...      ...
# 6141  5361        185        Amex           Credit   300609782832003  01/2024
# 6142  2711        185        Visa           Credit  4718517475996018  01/2021
# 6143  1305       1007  Mastercard           Credit  5929512204765914  08/2020
# 6144   743       1110  Mastercard            Debit  5589768928167462  01/2020
# 6145  3199       1110        Visa           Credit  4994011318343994  12/2020
#
# ...

# %% [markdown]
# # 1. SAMPEL DATA

# %% [markdown]
# # 1.1 Jumlah Data

# %%
import pandas as pd

data = pd.read_csv('C:/TUGAS SEMESTER 3/Pemrograman Lanjut/cards_data.csv')

jumlah_data = len(data)

jumlah_data_alt = data.shape[0]

print("Jumlah data:", jumlah_data)
# Out:
# Jumlah data: 6146

# %% [markdown]
# # 1.2 Sampel 10 Baris Data

# %%
import pandas as pd

# Contoh DataFrame
df = pd.read_csv('C:/TUGAS SEMESTER 3/Pemrograman Lanjut/cards_data.csv')

df = pd.DataFrame(df)

# Mengambil 10 sample baris
sample_rows = df.sample(n=10, random_state=42)

# Menampilkan hasil dengan format rapi
pd.set_option('display.colheader_justify', 'center')  # Header rata tengah
pd.set_option('display.width', 100)  # Atur lebar tampilan
pd.set_option('display.max_columns', None)  # Tampilkan semua kolom

print("Sample data 10 baris:")
print(sample_rows.to_string(index=False))  # Cetak tanpa index
# Out:
# Sample data 10 baris:
#  id   client_id card_brand card_type    card_number   expires  cvv has_chip  num_cards_issued credit_limit acct_open_date  year_pin_last_changed card_on_dark_web
# 5390    1572    Mastercard    Debit  5146038421358947 09/2021 676    YES            1              $946       11/2003              2015                 No
# 3414     597          Amex   Credit   309433518890778 08/2023 534    YES            1            $27500       06/2009              2009                 No
#  845     740          Visa    Debit  4456142342115909 03/2023 189    YES            2             $4009       01/2020              2020                 No
# 4133     592    Mastercard   Credit  5886410081258720 02/2020 684    YES            1             $5600       08/2004              2019                 No
# 2257    1974    Mastercard    Debit  5522110015947841 02/2024 663    YES            1            $14747       03/2010              2010                 No
# ...

# %% [markdown]
# # 1.3 Sampel Data Setiap Kolom

# %%
import pandas as pd

# Contoh DataFrame
df = pd.read_csv('C:/TUGAS SEMESTER 3/Pemrograman Lanjut/cards_data.csv')

df = pd.DataFrame(df)

# Fungsi untuk mengambil sample data dari setiap kolom
def sample_per_column(df, n=1):
    sample_data = {}
    for column in df.columns:
        sample_data[column] = df[column].sample(n=n, random_state=42).tolist()
    return sample_data

# Mendapatkan sample data (1 nilai dari setiap kolom)
sample_data = sample_per_column(df, n=1)

# Menampilkan hasil
print("Sample data dari setiap kolom:")
for column, sample in sample_data.items():
    print(f"{column}: {sample}")
# Out:
# Sample data dari setiap kolom:
# id: [5390]
# client_id: [1572]
# card_brand: ['Mastercard']
# card_type: ['Debit']
# card_number: [5146038421358947]
# expires: ['09/2021']
# cvv: [676]
# has_chip: ['YES']
# num_cards_issued: [1]
# credit_limit: ['$946']
# acct_open_date: ['11/2003']
# year_pin_last_changed: [2015]
# card_on_dark_web: ['No']

# %% [markdown]
# # 1.4. Data Terbesar dan Data Terkecil

# %% [markdown]
# # ASCENDING (data terkecil ke data terbesar)

# %%
df_sorted = df.apply(sorted, axis=0)
df_sorted
# Out:
#        id   client_id card_brand    card_type         card_number   expires   cvv has_chip  \
# 0        0       0       Amex              Credit   300105541992311  01/2002    0     NO
# 1        1       0       Amex              Credit   300609782832003  01/2006    0     NO
# 2        2       0       Amex              Credit   300717031458937  01/2007    0     NO
# 3        3       0       Amex              Credit   302014253634948  01/2008    0     NO
# 4        4       1       Amex              Credit   302031764623099  01/2008    1     NO
# ...    ...        ...        ...              ...               ...      ...  ...      ...
# 6141  6141    1998       Visa     Debit (Prepaid)  6987061746149197  12/2024  998    YES
# 6142  6142    1998       Visa     Debit (Prepaid)  6988770500713547  12/2024  999    YES
# 6143  6143    1998       Visa     Debit (Prepaid)  6994217664929322  12/2024  999    YES
# ...

# %% [markdown]
# # DESCENDING (Data Terbesar ke Data Terkecil)

# %%
df_sorted = df.apply(lambda col: sorted(col, reverse=True), axis=0)
df_sorted
# Out:
#        id   client_id card_brand    card_type         card_number   expires   cvv has_chip  \
# 0     6145    1999       Visa     Debit (Prepaid)  6997197066610978  12/2024  999    YES
# 1     6144    1999       Visa     Debit (Prepaid)  6994498161251218  12/2024  999    YES
# 2     6143    1998       Visa     Debit (Prepaid)  6994217664929322  12/2024  999    YES
# 3     6142    1998       Visa     Debit (Prepaid)  6988770500713547  12/2024  999    YES
# 4     6141    1998       Visa     Debit (Prepaid)  6987061746149197  12/2024  998    YES
# ...    ...        ...        ...              ...               ...      ...  ...      ...
# 6141     4       1       Amex              Credit   302031764623099  01/2008    1     NO
# 6142     3       0       Amex              Credit   302014253634948  01/2008    0     NO
# 6143     2       0       Amex              Credit   300717031458937  01/2007    0     NO
# ...

# %% [markdown]
# # 2. STATISTIK

# %% [markdown]
# # 2.1 Rata-rata dan Standar Deviasi dari kolom numerik

# %%
import pandas as pd

# Contoh DataFrame dengan data numerik

df = pd.read_csv('C:/TUGAS SEMESTER 3/Pemrograman Lanjut/cards_data.csv')
df = pd.DataFrame(data)

# Menghitung rata-rata dan standar deviasi hanya untuk kolom numerik
mean_values = df.select_dtypes(include=['number']).mean()  # Rata-rata untuk kolom numerik
std_values = df.select_dtypes(include=['number']).std()    # Standar deviasi untuk kolom numerik

# Menampilkan hasil
print("Rata-rata dari setiap kolom numerik:")
print(mean_values)

print("\nStandar deviasi dari setiap kolom numerik:")
print(std_values)
# Out:
# Rata-rata dari setiap kolom numerik:
# id                       3.072500e+03
# client_id                9.949396e+02
# card_number              4.820426e+15
# cvv                      5.062208e+02
# num_cards_issued         1.503091e+00
# year_pin_last_changed    2.013437e+03
# dtype: float64
#
# Standar deviasi dari setiap kolom numerik:
# id                       1.774342e+03
# client_id                5.786146e+02
# card_number              1.328582e+15
# cvv                      2.894311e+02
# num_cards_issued         5.191909e-01
# year_pin_last_changed    4.270699e+00
# dtype: float64

# %% [markdown]
# # 2.2 Modus (data yang pling sering muncul) pada kolom non-numerik

# %%
import pandas as pd

df = pd.read_csv('C:/TUGAS SEMESTER 3/Pemrograman Lanjut/cards_data.csv')
df = pd.DataFrame(df)

# Menghitung modus untuk kolom non-numerik
mode_values = df.select_dtypes(include=['object']).mode().iloc[0]  # Modus untuk kolom non-numerik


# Menampilkan hasil
print("Modus (data yang paling sering muncul) dari setiap kolom non-numerik:")
print(mode_values)
# Out:
# Modus (data yang paling sering muncul) dari setiap kolom non-numerik:
# card_brand          Mastercard
# card_type                Debit
# expires                02/2020
# has_chip                   YES
# credit_limit                $0
# acct_open_date         02/2020
# card_on_dark_web            No
# Name: 0, dtype: object

# %% [markdown]
# # 2.3 Percentile dari kolom numerik

# %%
import pandas as pd

# Membaca DataFrame dari file CSV
df = pd.read_csv('C:/TUGAS SEMESTER 3/Pemrograman Lanjut/cards_data.csv')

# Memfilter hanya kolom numerik
numeric_df = df.select_dtypes(include=['number'])

# Mendefinisikan persentil yang ingin dihitung
percentiles = [0.10, 0.25, 0.50, 0.75, 0.90]

# Menghitung quantile untuk setiap kolom numerik
percentile_values = numeric_df.quantile(percentiles)

# Menampilkan hasil
print("Percentile (10%, 25%, 50%, 75%, 90%) dari setiap kolom:")
print(percentile_values)
# Out:
# Percentile (10%, 25%, 50%, 75%, 90%) dari setiap kolom:
#         id     client_id   card_number   cvv   num_cards_issued  year_pin_last_changed
# 0.10   614.50    197.00   4.086688e+15   99.0         1.0               2009.0
# 0.25  1536.25    492.25   4.486365e+15  257.0         1.0               2010.0
# 0.50  3072.50    992.00   5.108957e+15  516.5         1.0               2013.0
# 0.75  4608.75   1495.00   5.585237e+15  756.0         2.0               2017.0
# 0.90  5530.50   1799.00   5.879344e+15  902.5         2.0               2020.0

# %% [markdown]
# # 2.4 NILAI EKSTREMUM

# %%
import pandas as pd

# Membaca DataFrame dari file CSV
df = pd.read_csv('C:/TUGAS SEMESTER 3/Pemrograman Lanjut/cards_data.csv')

# Memfilter hanya kolom numerik
numeric_df = df.select_dtypes(include=['number'])

# Mencari nilai minimum dan maksimum untuk setiap kolom numerik
min_values = numeric_df.min()
max_values = numeric_df.max()

# Menampilkan hasil
print("Nilai Minimum dari setiap kolom numerik:")
print(min_values)

print("\nNilai Maksimum dari setiap kolom numerik:")
print(max_values)
# Out:
# Nilai Minimum dari setiap kolom numerik:
# id                                     0
# client_id                              0
# card_number              300105541992311
# cvv                                    0
# num_cards_issued                       1
# year_pin_last_changed               2002
# dtype: int64
#
# Nilai Maksimum dari setiap kolom numerik:
# id                                   6145
# client_id                            1999
# card_number              6997197066610978
# cvv                                   999
# num_cards_issued                        3
# year_pin_last_changed                2020
# dtype: int64

# %% [markdown]
# # 2.5 Distribusi Frekuensi Data Non-numerik

# %%
import pandas as pd

# Membaca DataFrame dari file CSV
df = pd.read_csv('C:/TUGAS SEMESTER 3/Pemrograman Lanjut/cards_data.csv')

# Misalkan kita ingin menghitung distribusi frekuensi untuk kolom 'kategori'
# Gantilah 'kategori' dengan nama kolom yang sesuai
if 'card_type' in df.columns:
    frequency_distribution = df['card_type'].value_counts()

    # Menampilkan hasil
    print("Distribusi Frekuensi untuk kolom 'card_type':")
    print(frequency_distribution)
else:
    print("Kolom 'card_type' tidak ditemukan dalam DataFrame.")
# Out:
# Distribusi Frekuensi untuk kolom 'card_type':
# card_type
# Debit              3511
# Credit             2057
# Debit (Prepaid)     578
# Name: count, dtype: int64

# %%
import pandas as pd

# Membaca DataFrame dari file CSV
df = pd.read_csv('C:/TUGAS SEMESTER 3/Pemrograman Lanjut/cards_data.csv')

# Memfilter hanya kolom numerik
numeric_df = df.select_dtypes(include=['number'])

# Misalkan kita ingin menghitung distribusi frekuensi untuk kolom 'nilai'
# Gantilah 'nilai' dengan nama kolom yang sesuai
if 'year_pin_last_changed' in numeric_df.columns:
    # Membuat bin untuk distribusi frekuensi
    bins = pd.cut(numeric_df['year_pin_last_changed'], bins=10)  # Menggunakan 10 bin
    frequency_distribution = bins.value_counts().sort_index()

    # Menampilkan hasil
    print("Distribusi Frekuensi untuk kolom 'year_pin_last_changed':")
    print(frequency_distribution)
else:
    print("Kolom 'year_pin_last_changed' tidak ditemukan dalam DataFrame.")
# Out:
# Distribusi Frekuensi untuk kolom 'year_pin_last_changed':
# year_pin_last_changed
# (2001.982, 2003.8]      13
# (2003.8, 2005.6]        48
# (2005.6, 2007.4]       250
# (2007.4, 2009.2]       759
# (2009.2, 2011.0]      1521
# (2011.0, 2012.8]       477
# (2012.8, 2014.6]       862
# (2014.6, 2016.4]       575
# (2016.4, 2018.2]       318
# (2018.2, 2020.0]      1323
# Name: count, dtype: int64

# %% [markdown]
# # 3. VISUALISASI

# %% [markdown]
# # 3.1 VISUALISASI DALAM BENTUK GRAFIK

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Membaca dataset
df = pd.read_csv('C:/TUGAS SEMESTER 3/Pemrograman Lanjut/cards_data.csv')

# %% [markdown]
# # 3.1.1 PERBANDINGAN KATEGORI

# %%
plt.figure(figsize=(12, 5))

# Bar Chart: Jumlah kartu yang dikeluarkan
plt.subplot(1, 2, 1)
df['num_cards_issued'].value_counts().plot(kind='bar')
plt.title('Distribusi Jumlah Kartu yang Dikeluarkan')
plt.xlabel('Jumlah Kartu')
plt.ylabel('Frekuensi')
# Out:
# Text(0, 0.5, 'Frekuensi')

# %% [markdown]
# # 3.1.2 PROPORSI TAHUN PERUBAHAN PIN

# %%
# Pie Chart: Proporsi tahun perubahan PIN
plt.subplot(1, 2, 2)
df['year_pin_last_changed'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Proporsi Tahun Perubahan PIN')
plt.ylabel('')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 3.1.3 PERUBAHAN TERHADAP WAKTU

# %%
df_sorted = df.sort_values('year_pin_last_changed').head(50)
df_sorted.plot(x='year_pin_last_changed', y='id', kind='line', figsize=(12, 5))
plt.title('Trend Tahun Perubahan PIN (50 Data Pertama)')
plt.xlabel('Tahun')
plt.ylabel('ID')
# Out:
# Text(0, 0.5, 'ID')

# %% [markdown]
# # 3.1.4 DISTRIBUSI KUMULATIF KARTU

# %%
# Area Plot: Distribusi kumulatif kartu
plt.subplot(1, 2, 2)
df['num_cards_issued'].value_counts().sort_index().cumsum().plot(kind='area')
plt.title('Distribusi Kumulatif Jumlah Kartu')
plt.xlabel('Jumlah Kartu')
plt.ylabel('Frekuensi Kumulatif')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 3.1.5 HUBUNGAN ANTARA JUMLAH KARTU DAN TAHUN PERUBAHAN PIN

# %%
plt.figure(figsize=(12, 5))

# Grouped Bar: Hubungan antara jumlah kartu dan tahun perubahan PIN
grouped_data = df.groupby(['num_cards_issued', 'year_pin_last_changed']).size().unstack()
grouped_data.plot(kind='bar', stacked=True)
plt.title('Hubungan Jumlah Kartu dan Tahun Perubahan PIN')
plt.xlabel('Jumlah Kartu')
plt.ylabel('Frekuensi')
plt.legend(title='Tahun Perubahan PIN', bbox_to_anchor=(1.05, 1))
plt.tight_layout()
plt.show()

# %% [markdown]
# # 3.1.6 PLOTTING RELATIONSHIP

# %%
plt.figure(figsize=(12, 5))

# Scatter Plot: Hubungan antara ID dan tahun perubahan PIN
plt.subplot(1, 2, 1)
plt.scatter(df['id'], df['year_pin_last_changed'], alpha=0.5)
plt.title('Hubungan ID dan Tahun Perubahan PIN')
plt.xlabel('ID')
plt.ylabel('Tahun Perubahan PIN')

# Heatmap: Korelasi antar variabel numerik
plt.subplot(1, 2, 2)
numeric_cols = df.select_dtypes(include=[np.number]).columns
correlation = df[numeric_cols].corr()
sns.heatmap(correlation, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Heatmap Korelasi Variabel')
plt.tight_layout()
plt.show()

# Menambahkan statistik deskriptif
print("\nStatistik Deskriptif:")
print(df.describe())

# Menampilkan informasi missing values
print("\nInformasi Missing Values:")
print(df.isnull().sum())
# Out:
# Statistik Deskriptif:
#            id        client_id    card_number      cvv      num_cards_issued  \
# count  6146.000000  6146.000000  6.146000e+03  6146.000000     6146.000000
# mean   3072.500000   994.939636  4.820426e+15   506.220794        1.503091
# std    1774.341709   578.614626  1.328582e+15   289.431123        0.519191
# min       0.000000     0.000000  3.001055e+14     0.000000        1.000000
# 25%    1536.250000   492.250000  4.486365e+15   257.000000        1.000000
# 50%    3072.500000   992.000000  5.108957e+15   516.500000        1.000000
# 75%    4608.750000  1495.000000  5.585237e+15   756.000000        2.000000
# max    6145.000000  1999.000000  6.997197e+15   999.000000        3.000000
#
#        year_pin_last_changed
# count       6146.000000
# mean        2013.436707
# std            4.270699
# min         2002.000000
# 25%         2010.000000
# 50%         2013.000000
# 75%         2017.000000
# max         2020.000000
#
# Informasi Missing Values:
# ...

# %% [markdown]
# # 4. NILAI KORELASI ANTARA KOLOM ID DENGAN CLIENT_ID

# %%
correlation = df['id'].corr(df['client_id'])
print(correlation)
# Out:
# 0.018311307160883684

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Membaca data CSV
df = pd.read_csv('C:/TUGAS SEMESTER 3/Pemrograman Lanjut/cards_data.csv')

# Fungsi untuk analisis korelasi
def analisis_korelasi(dataframe):
    # 1. Mengambil hanya kolom numerik untuk analisis korelasi
    dataframe_numerik = dataframe.select_dtypes(include=['number'])
    
    # 2. Menghitung korelasi
    korelasi = dataframe_numerik.corr()
    
    # 3. Membuat visualisasi heatmap
    plt.figure(figsize=(10, 8))
    sns.heatmap(korelasi, annot=True, cmap='coolwarm', vmin=-1, vmax=1, center=0)
    plt.title('Matriks Korelasi')
    plt.show()
    
    # 4. Membuat scatter plot untuk semua pasangan variabel
    plt.figure(figsize=(12, 10))
    sns.pairplot(dataframe_numerik)
    plt.suptitle('Scatter Plot Matrix', y=1.02)
    plt.show()
    
    # 5. Mencetak interpretasi korelasi
    print("\nInterpretasi Korelasi:")
    for col1 in dataframe_numerik.columns:
        for col2 in dataframe_numerik.columns:
            if col1 < col2:  # Menghindari pengulangan
                corr = korelasi.loc[col1, col2]
                interpretasi = interpret_correlation(corr)
                print(f"{col1} dengan {col2}: {corr:.3f} ({interpretasi})")

# Fungsi untuk interpretasi nilai korelasi
def interpret_correlation(value):
    abs_value = abs(value)
    if abs_value >= 0.8:
        return "Korelasi sangat kuat"
    elif abs_value >= 0.6:
        return "Korelasi kuat"
    elif abs_value >= 0.4:
        return "Korelasi sedang"
    elif abs_value >= 0.2:
        return "Korelasi lemah"
    else:
        return "Korelasi sangat lemah"

# Menjalankan analisis
print("Analisis Korelasi:")
print("==================")
analisis_korelasi(df)
# Out:
# Analisis Korelasi:
# ...
# Interpretasi Korelasi:
# id dengan num_cards_issued: -0.024 (Korelasi sangat lemah)
# id dengan year_pin_last_changed: -0.381 (Korelasi lemah)
# client_id dengan id: 0.018 (Korelasi sangat lemah)
# client_id dengan cvv: -0.011 (Korelasi sangat lemah)
# client_id dengan num_cards_issued: -0.013 (Korelasi sangat lemah)
# client_id dengan year_pin_last_changed: -0.010 (Korelasi sangat lemah)
# card_number dengan id: 0.017 (Korelasi sangat lemah)
# card_number dengan client_id: 0.000 (Korelasi sangat lemah)
# card_number dengan cvv: -0.009 (Korelasi sangat lemah)
# card_number dengan num_cards_issued: -0.005 (Korelasi sangat lemah)
# card_number dengan year_pin_last_changed: -0.013 (Korelasi sangat lemah)
# cvv dengan id: -0.012 (Korelasi sangat lemah)
# cvv dengan num_cards_issued: -0.000 (Korelasi sangat lemah)
# cvv dengan year_pin_last_changed: 0.013 (Korelasi sangat lemah)
# num_cards_issued dengan year_pin_last_changed: -0.014 (Korelasi sangat lemah)
